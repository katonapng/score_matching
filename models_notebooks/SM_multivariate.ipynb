# %%
import json
import os
import sys
import time

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from scipy.stats import chi2
from tqdm import tqdm

parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.insert(0, parent_dir)

from dataloader import FastTensorDataLoader

# %% [markdown]
# ## Data Generation

# %%
def generate_samples(mean, cov, d, m, n):
    """
    Generate a list of samples drawn from a normal distribution (1D or multivariate).

    Args:
        mean (torch.Tensor): Mean of the normal distribution.
        cov (torch.Tensor): Covariance matrix.
        d (int): Number of dimensions for each sample.
        m (int): Number of samples to generate.
        n (int): Number of elements in each sample.

    Returns:
        list[torch.Tensor]: A list of `m` tensors.
            - For d > 1: Each tensor has shape (n, d).
            - For d = 1: Each tensor has shape (n, 1).
    """
    samples = []
    if mean.shape[0] != d or cov.shape != (d, d):
        raise ValueError("For d > 1, 'mean' must have shape (d,) and 'cov' must have shape (d, d).")
    distribution = torch.distributions.MultivariateNormal(mean, covariance_matrix=cov)
    for _ in range(m):
        sample = distribution.sample((n,))  # Generate n samples for each tensor
        samples.append(sample.clone())
    
    return samples

# %%
mu = torch.tensor([0.0, 0.0])
cov = torch.tensor([[1.0, 0.0], [0.0, 1.0]])
m, n = 100, 1000
dim = mu.shape[-1]
samples = generate_samples(mu, cov, dim, m, n)

# %%
train_size = int(0.8 * m)
test_size = m - train_size

X = torch.stack(samples, dim=0)

X_train = X[:train_size]
X_test = X[train_size:]

loader_train = FastTensorDataLoader(X_train, batch_size=32, shuffle=False)
loader_test = FastTensorDataLoader(X_test, batch_size=32, shuffle=False)

# %% [markdown]
# ## Model

# %%
class Gaussian(nn.Module):
    def __init__(self, dimensions):
        super(Gaussian, self).__init__()
        torch.manual_seed(123)
        self.mu = nn.Parameter(torch.randn(dimensions, dtype=torch.float64))
        self.M = nn.Parameter(torch.randn(size=[dimensions, dimensions], dtype=torch.float64))
        A = torch.randn(dimensions, dimensions, dtype=torch.float64)
        self.M = nn.Parameter(torch.mm(A, A.T))    
        self.M.data += dimensions * torch.eye(dimensions, dtype=torch.float64)
        
    def forward(self, x):
        diff = x - self.mu
        return -0.5 * torch.einsum('bpi,ij,bpj->bp', diff, self.M, diff)

    def compute_psi(self, x):
        x.requires_grad_()
        nn_output = self.forward(x)
        psi = torch.autograd.grad(nn_output, x, grad_outputs=torch.ones_like(nn_output), create_graph=True)[0]
        return psi
    
    def gaussian_psi(self, x):
        diff = x - self.mu
        return -torch.einsum('ij,bpj->bpi', self.M, diff)
    
    def gaussian_J(self, x, length):
        diff = x - self.mu
        trace_term = -torch.trace(self.M)
        quadratic_term = torch.einsum('bpi,ij,bpj->bp', diff, self.M @ self.M, diff)

        J_value = 0.5*quadratic_term + trace_term
        J_value = J_value.sum(dim=-1) / length

        return J_value.mean()
    
    def loss(self, x):
        length = len(x[0])
        psi_x = self.compute_psi(x).float()
        psi_x_real = self.gaussian_psi(x).float()
        if not torch.allclose(psi_x, psi_x_real, atol=1e-4):
            raise ValueError(
                f"Calculated psi value {psi_x} \
                is different from the analytical solution {psi_x_real}"
                )

        norm_squared = (psi_x ** 2).sum(dim=-1) 

        divergence = 0
        for i in range(x.shape[-1]): 
            gradient = torch.autograd.grad(psi_x[..., i].sum(), x, retain_graph=True, create_graph=True)[0]
            divergence += gradient[..., i]  
        
        total_loss = 0.5 * norm_squared + divergence
        total_loss = total_loss.sum(dim=-1)/length
        total_loss = total_loss.mean().float()

        J = self.gaussian_J(x, length).float()
        if not torch.allclose(total_loss, J, atol=1e-4):
            raise ValueError(
                f"Calculated psi value {total_loss} \
                is different from the analytical solution {J}"
                )
        
        return total_loss, J

# %%
def optimize_theta_gaussian(
        loader_train, dim, num_epochs=1000, learning_rate_mu=1e-3,
        learning_rate_M=1e-4
    ):
    model = Gaussian(dim)
    optimizer = torch.optim.Rprop(
        [
            {"params": [model.mu], "lr": learning_rate_mu},
            {"params": [model.M], "lr": learning_rate_M},
        ]
    )
    avg_epoch_losses = []
    avg_epoch_real_losses = []
    avg_estimated_mus = []
    avg_estimated_covs = []

    pbar = tqdm(range(num_epochs), desc="Training", unit="epoch")

    for _ in pbar:
        epoch_loss_sum = 0
        epoch_real_loss_sum = 0
        num_batches = len(loader_train)

        batch_mus = []
        batch_covs = []

        start_time = time.time()
        for X_batch in loader_train:
            optimizer.zero_grad()

            loss, real_loss = model.loss(X_batch[0])

            loss.backward()
            optimizer.step()

            batch_loss = loss.item()
            batch_real_loss = real_loss.item()
            epoch_loss_sum += batch_loss
            epoch_real_loss_sum += batch_real_loss

            # Store current batch estimates
            batch_mus.append(model.mu.detach().numpy().copy())
            batch_covs.append(model.M.detach().numpy().copy())

        avg_loss = epoch_loss_sum / num_batches
        avg_real_loss = epoch_real_loss_sum / num_batches
        avg_epoch_losses.append(avg_loss)
        avg_epoch_real_losses.append(avg_real_loss)

        # Compute per-epoch averages of estimated mus and covs
        avg_estimated_mus.append(sum(batch_mus) / len(batch_mus))
        avg_estimated_covs.append(sum(batch_covs) / len(batch_covs))

        elapsed_time = time.time() - start_time
        pbar.set_postfix({
            "Train Loss": f"{avg_loss:.4f}",
            "Real Loss": f"{avg_real_loss:.4f}",
            "Time/Epoch": f"{elapsed_time:.2f}s"
        })
    
    return model, avg_epoch_losses, avg_epoch_real_losses, avg_estimated_mus, avg_estimated_covs

# %%
epochs = 100
model, losses, real_losses, estimated_mus, estimated_cov = optimize_theta_gaussian(
    loader_train, dim, num_epochs=epochs, learning_rate_mu=1e-3, learning_rate_M=1e-3,
    )
# Out:
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.26epoch/s, Train Loss=-0.9987, Real Loss=-0.9987, Time/Epoch=0.08s]

# %%
plt.plot(losses, label="Score matching loss")
plt.plot(real_losses, label="Analytical loss", linestyle='--')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Convergence for Score Matching')
plt.grid(True)
plt.legend()
plt.show()

# %%
estimated_mus = np.array(estimated_mus)  # (epochs, d)
d = estimated_mus.shape[1]
colors_mu = plt.cm.viridis(np.linspace(0, 1, d))

plt.figure(figsize=(10, 5))
for i in range(d):
    plt.plot(estimated_mus[:, i], label=f"Estimated μ{i+1}")
    plt.axhline(
        mu[i] + 0.001 * (i + 1), 
        linestyle='--', color=colors_mu[i], label=f"True μ{i+1}")

plt.xlabel('Epoch')
plt.ylabel('Value')
plt.grid(True)
plt.legend()
plt.title('Convergence of μ Parameters')
plt.show()

estimated_covs_array = np.array(torch.linalg.inv(torch.tensor(estimated_cov)))
epochs, d, _ = estimated_covs_array.shape


colors_cov = plt.cm.plasma(np.linspace(0, 1, d * d))
color_map = np.reshape(colors_cov, (d, d, 4))
jitter = 0.01
plt.figure(figsize=(10, 5))
for i in range(d):
    for j in range(d):
        plt.plot(estimated_covs_array[:, i, j], label=f"Estimated σ{i+1}{j+1}")
        if i == j:  # Diagonal elements 
            plt.axhline(cov[i, j] + jitter * (1 if i % 2 == 0 else -1), linestyle='--', color=color_map[i, j], label=f"True σ{i+1}{j+1}")
        elif i < j:  # Off-diagonal unique pairs 
            plt.axhline(cov[i, j] + jitter, linestyle='--', color=color_map[i, j], label=f"True σ{i+1}{j+1}")
        else:  # Symmetric off-diagonal elements
            plt.axhline(cov[i, j] - jitter, linestyle='--', color=color_map[i, j], label=f"True σ{i+1}{j+1}")


plt.xlabel('Epoch')
plt.ylabel('Value')
plt.grid(True)
plt.legend(loc='upper right')
plt.title('Convergence of  Σ')
plt.show()
# Out:
# C:\Users\79217\AppData\Local\Temp\ipykernel_21068\828911225.py:19: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:281.)
#   estimated_covs_array = np.array(torch.linalg.inv(torch.tensor(estimated_cov)))
# C:\Users\79217\AppData\Local\Temp\ipykernel_21068\828911225.py:19: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   estimated_covs_array = np.array(torch.linalg.inv(torch.tensor(estimated_cov)))

# %%
print("Final estimated μ:", estimated_mus[-1])
print("True μ:", mu)
print("\nFinal estimated Σ:\n", torch.linalg.inv(torch.tensor(estimated_cov[-1])))
print("True Σ:\n", cov)
# Out:
# Final estimated μ: [-0.00229265 -0.00275996]
# True μ: tensor([0., 0.])
#
# Final estimated Σ:
#  tensor([[1.0047, 0.0036],
#         [0.0036, 1.0001]], dtype=torch.float64)
# True Σ:
#  tensor([[1., 0.],
#         [0., 1.]])

# %% [markdown]
# ## Statistical Significance

# %%
num_trials = 100
epochs = 100
learning_rate_mu = 1e-3
learning_rate_M = 1e-3

# %%
true_mu = []
true_cov = []
estimated_mu = []
estimated_cov = []

# %%
json_file = f'data/trial_results_multivariate.json'

# %%
if os.path.exists(json_file):
    with open(json_file, 'r') as f:
        trial_results = json.load(f)
else:
    trial_results = []

n = 1000 # trials
m = 100 # samples per trial
dim = 2
num_points = 1000
for trial in tqdm(range(num_trials), desc="Running trials"):
    torch.seed()
    mu = torch.empty(2).uniform_(-2, 2)
    random_matrix = torch.rand(2, 2)
    cov = torch.mm(random_matrix.T, random_matrix)

    samples = generate_samples(mu, cov, dim, m, n)
    X = torch.stack(samples, dim=0)
    loader_train = FastTensorDataLoader(X, batch_size=32, shuffle=False)
    
    _, _, _, estimated_mu, estimated_cov = optimize_theta_gaussian(
        loader_train, dim, num_epochs=epochs,
        learning_rate_mu=learning_rate_mu,
        learning_rate_M=learning_rate_M)
    
    trial_result = {
        "trial": trial,
        "epochs": epochs,
        "lr_mu": learning_rate_mu,
        "lr_M": learning_rate_M,
        "true_mu": mu.tolist(),
        "true_cov": cov.tolist(),
        "estimated_mu": estimated_mu[-1].tolist(),
        "estimated_cov": torch.linalg.inv(torch.tensor(estimated_cov[-1])).tolist(),
    }
    trial_results.append(trial_result)
    
    with open(json_file, mode='w') as f:
        json.dump(trial_results, f, indent=4)
# Out:
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.32epoch/s, Train Loss=-57.2064, Real Loss=-57.2064, Time/Epoch=0.10s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.17epoch/s, Train Loss=-12.4450, Real Loss=-12.4450, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.13epoch/s, Train Loss=-871.2535, Real Loss=-871.2535, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.28epoch/s, Train Loss=-4.7129, Real Loss=-4.7129, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:11<00:00,  8.76epoch/s, Train Loss=-4.3630, Real Loss=-4.3630, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:11<00:00,  8.50epoch/s, Train Loss=-3080.8397, Real Loss=-3080.8397, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.38epoch/s, Train Loss=-6.6521, Real Loss=-6.6521, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.77epoch/s, Train Loss=-5.9682, Real Loss=-5.9682, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.41epoch/s, Train Loss=-52.4784, Real Loss=-52.4784, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.40epoch/s, Train Loss=-97.2292, Real Loss=-97.2292, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.67epoch/s, Train Loss=-20.2585, Real Loss=-20.2585, Time/Epoch=0.07s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.55epoch/s, Train Loss=-29.7425, Real Loss=-29.7425, Time/Epoch=0.24s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.82epoch/s, Train Loss=-21.1012, Real Loss=-21.1012, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.63epoch/s, Train Loss=-4.2084, Real Loss=-4.2084, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.27epoch/s, Train Loss=-38.0978, Real Loss=-38.0978, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.23epoch/s, Train Loss=-108.1116, Real Loss=-108.1116, Time/Epoch=0.12s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.36epoch/s, Train Loss=-5.4171, Real Loss=-5.4171, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.48epoch/s, Train Loss=-19.8706, Real Loss=-19.8706, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.70epoch/s, Train Loss=-16.2089, Real Loss=-16.2089, Time/Epoch=0.07s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.54epoch/s, Train Loss=-17.9681, Real Loss=-17.9681, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.50epoch/s, Train Loss=-2.3090, Real Loss=-2.3090, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.75epoch/s, Train Loss=-23.7450, Real Loss=-23.7450, Time/Epoch=0.23s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.70epoch/s, Train Loss=-7.2161, Real Loss=-7.2161, Time/Epoch=0.10s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.63epoch/s, Train Loss=-1334.2092, Real Loss=-1334.2092, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.42epoch/s, Train Loss=-10.0953, Real Loss=-10.0953, Time/Epoch=0.10s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.71epoch/s, Train Loss=-2.5281, Real Loss=-2.5281, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.56epoch/s, Train Loss=-47.1707, Real Loss=-47.1707, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.69epoch/s, Train Loss=-30.9492, Real Loss=-30.9492, Time/Epoch=0.07s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 11.03epoch/s, Train Loss=-1654.9283, Real Loss=-1654.9283, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.90epoch/s, Train Loss=-330.5474, Real Loss=-330.5474, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:08<00:00, 11.27epoch/s, Train Loss=-87.9760, Real Loss=-87.9760, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:08<00:00, 11.15epoch/s, Train Loss=-123.7995, Real Loss=-123.7995, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.83epoch/s, Train Loss=-2.0709, Real Loss=-2.0709, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.85epoch/s, Train Loss=-5.2981, Real Loss=-5.2981, Time/Epoch=0.07s]
# Training: 100%|██████████| 100/100 [00:08<00:00, 11.29epoch/s, Train Loss=-16.3072, Real Loss=-16.3072, Time/Epoch=0.07s]
# Training: 100%|██████████| 100/100 [00:08<00:00, 11.30epoch/s, Train Loss=-413.3942, Real Loss=-413.3942, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.96epoch/s, Train Loss=-4.7316, Real Loss=-4.7316, Time/Epoch=0.07s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.91epoch/s, Train Loss=-18.3614, Real Loss=-18.3614, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.90epoch/s, Train Loss=-1.5283, Real Loss=-1.5283, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.86epoch/s, Train Loss=-9.7402, Real Loss=-9.7402, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.99epoch/s, Train Loss=-3.1541, Real Loss=-3.1541, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.61epoch/s, Train Loss=-26.4183, Real Loss=-26.4183, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.99epoch/s, Train Loss=-5.1358, Real Loss=-5.1358, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 11.08epoch/s, Train Loss=-3.8540, Real Loss=-3.8540, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.81epoch/s, Train Loss=-3.4750, Real Loss=-3.4750, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:08<00:00, 11.12epoch/s, Train Loss=-15.9859, Real Loss=-15.9859, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:08<00:00, 11.27epoch/s, Train Loss=-4.3583, Real Loss=-4.3583, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:08<00:00, 11.39epoch/s, Train Loss=-15.1178, Real Loss=-15.1178, Time/Epoch=0.07s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.67epoch/s, Train Loss=-71.8460, Real Loss=-71.8460, Time/Epoch=0.07s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.94epoch/s, Train Loss=-2.4583, Real Loss=-2.4583, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.83epoch/s, Train Loss=-247.3152, Real Loss=-247.3153, Time/Epoch=0.07s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.62epoch/s, Train Loss=-11.5626, Real Loss=-11.5626, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.90epoch/s, Train Loss=-10.0909, Real Loss=-10.0909, Time/Epoch=0.10s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.53epoch/s, Train Loss=-56.8300, Real Loss=-56.8300, Time/Epoch=0.10s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.30epoch/s, Train Loss=-8.2781, Real Loss=-8.2781, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.38epoch/s, Train Loss=-6.5606, Real Loss=-6.5606, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.56epoch/s, Train Loss=-74.7278, Real Loss=-74.7278, Time/Epoch=0.10s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.62epoch/s, Train Loss=-43.5326, Real Loss=-43.5326, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.69epoch/s, Train Loss=-4.0015, Real Loss=-4.0015, Time/Epoch=0.11s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 11.07epoch/s, Train Loss=-10.5160, Real Loss=-10.5160, Time/Epoch=0.07s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.42epoch/s, Train Loss=-802.6867, Real Loss=-802.6867, Time/Epoch=0.07s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.36epoch/s, Train Loss=-31.6749, Real Loss=-31.6749, Time/Epoch=0.10s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.20epoch/s, Train Loss=-376.7756, Real Loss=-376.7756, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.34epoch/s, Train Loss=-3.0524, Real Loss=-3.0524, Time/Epoch=0.10s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.30epoch/s, Train Loss=-5.8925, Real Loss=-5.8925, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.44epoch/s, Train Loss=-15.9668, Real Loss=-15.9668, Time/Epoch=0.10s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.28epoch/s, Train Loss=-7.0655, Real Loss=-7.0655, Time/Epoch=0.10s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.43epoch/s, Train Loss=-3.5776, Real Loss=-3.5776, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.25epoch/s, Train Loss=-182.1651, Real Loss=-182.1651, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.16epoch/s, Train Loss=-7.6733, Real Loss=-7.6733, Time/Epoch=0.10s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.30epoch/s, Train Loss=-37.6346, Real Loss=-37.6346, Time/Epoch=0.10s]
# Training: 100%|██████████| 100/100 [00:11<00:00,  9.03epoch/s, Train Loss=-5.7043, Real Loss=-5.7043, Time/Epoch=0.10s]
# Training: 100%|██████████| 100/100 [00:11<00:00,  9.05epoch/s, Train Loss=-28.7118, Real Loss=-28.7118, Time/Epoch=0.10s]
# Training: 100%|██████████| 100/100 [00:11<00:00,  9.09epoch/s, Train Loss=-1.1746, Real Loss=-1.1746, Time/Epoch=0.10s]
# Training: 100%|██████████| 100/100 [00:11<00:00,  8.93epoch/s, Train Loss=-77.2944, Real Loss=-77.2943, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.81epoch/s, Train Loss=-42.0483, Real Loss=-42.0483, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.74epoch/s, Train Loss=-7.9624, Real Loss=-7.9624, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.32epoch/s, Train Loss=-3.0149, Real Loss=-3.0149, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.61epoch/s, Train Loss=-52.8830, Real Loss=-52.8830, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.73epoch/s, Train Loss=-81.4213, Real Loss=-81.4213, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.21epoch/s, Train Loss=-307.0330, Real Loss=-307.0330, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.28epoch/s, Train Loss=-3.9093, Real Loss=-3.9093, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.48epoch/s, Train Loss=-4.5553, Real Loss=-4.5553, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.28epoch/s, Train Loss=-34.3077, Real Loss=-34.3077, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.58epoch/s, Train Loss=-89.1126, Real Loss=-89.1126, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.67epoch/s, Train Loss=-3.3750, Real Loss=-3.3750, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.58epoch/s, Train Loss=-155.4293, Real Loss=-155.4293, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.59epoch/s, Train Loss=-10.7521, Real Loss=-10.7521, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.62epoch/s, Train Loss=-17.1530, Real Loss=-17.1530, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:09<00:00, 10.35epoch/s, Train Loss=-12.9022, Real Loss=-12.9022, Time/Epoch=0.08s]
# Training: 100%|██████████| 100/100 [00:11<00:00,  8.41epoch/s, Train Loss=-846.6095, Real Loss=-846.6095, Time/Epoch=0.11s]
# Training: 100%|██████████| 100/100 [00:11<00:00,  8.96epoch/s, Train Loss=-247.6645, Real Loss=-247.6645, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.10epoch/s, Train Loss=-4.4000, Real Loss=-4.4000, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.14epoch/s, Train Loss=-7.7691, Real Loss=-7.7691, Time/Epoch=0.12s]
# Training: 100%|██████████| 100/100 [00:11<00:00,  9.05epoch/s, Train Loss=-424.6879, Real Loss=-424.6880, Time/Epoch=0.11s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.15epoch/s, Train Loss=-98.5441, Real Loss=-98.5441, Time/Epoch=0.10s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.21epoch/s, Train Loss=-2.3136, Real Loss=-2.3136, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.37epoch/s, Train Loss=-10.7828, Real Loss=-10.7828, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.36epoch/s, Train Loss=-18.0411, Real Loss=-18.0411, Time/Epoch=0.09s]
# Training: 100%|██████████| 100/100 [00:10<00:00,  9.13epoch/s, Train Loss=-3.2080, Real Loss=-3.2080, Time/Epoch=0.09s]
# Running trials: 100%|██████████| 100/100 [16:31<00:00,  9.91s/it]

# %%
with open(json_file, mode='r') as f:
    trial_results = json.load(f)

true_mu = np.array([trial['true_mu'] for trial in trial_results])
true_cov = np.array([trial['true_cov'] for trial in trial_results])
estimated_mu = np.array([trial['estimated_mu'] for trial in trial_results])
estimated_cov = np.array([trial['estimated_cov'] for trial in trial_results])

# %%
p = 2  

# Compute Mahalanobis distances
D_squared = []
for i in range(num_trials):
    mean_diff = estimated_mu[i] - true_mu[i]
    cov_inv = np.linalg.inv(true_cov[i])
    D2 = np.dot(np.dot(mean_diff.T, cov_inv), mean_diff)  # Mahalanobis distance squared
    D_squared.append(D2)

D_squared = np.array(D_squared)

# Perform Chi-Squared Test
chi2_critical = chi2.ppf(0.95, df=p)  # Critical value for 95% confidence
significant_indices = np.where(D_squared > chi2_critical)[0]
significant_trials = np.sum(D_squared > chi2_critical)  # Count significant deviations
p_values = 1 - chi2.cdf(D_squared, df=p)  # Compute p-values for each trial

print(f"Number of significant trials: {significant_trials}/{num_trials}")
print(f"Mean p-value: {np.mean(p_values)}")

if significant_trials > 0:
    print("There are statistically significant deviations in some trials.")
    print("Significant trials details:")
    for idx in significant_indices:
        print(f"Trial {idx}:")
        print(f"  p-value = {p_values[idx]}")
        print(f"  True μ = {true_mu[idx]}")
        print(f"  Estimated μ = {estimated_mu[idx]}")
else:
    print("No statistically significant deviations detected.")
# Out:
# Number of significant trials: 0/100
# Mean p-value: 0.9451993972979613
# No statistically significant deviations detected.

# %%
df = p * (p + 1) // 2  # Degrees of freedom for covariance matrix
test_statistics = []
skipped_trials = 0

for i in range(num_trials):
    true_det = np.linalg.det(true_cov[i])
    pred_det = np.linalg.det(estimated_cov[i])
    
    # Skip invalid determinants
    if pred_det <= 0:
        skipped_trials += 1
        continue

    true_inv = np.linalg.inv(true_cov[i])
    trace_term = np.trace(np.dot(true_inv, estimated_cov[i]))
    log_det_term = np.log(true_det) - np.log(pred_det)
    
    # Compute test statistic (Lambda)
    test_stat = num_trials * (log_det_term + trace_term - p)
    test_statistics.append(test_stat)

test_statistics = np.array(test_statistics)
p_values = 1 - chi2.cdf(test_statistics, df=df)
significant_indices = np.where(p_values < 0.05)[0]
significant_trials = len(significant_indices)

# Print results
print(f"Number of significant trials: {significant_trials}/{num_trials}")
print(f"Mean p-value: {np.mean(p_values):.4f}")
print(f"Skipped trials due to invalid determinants: {skipped_trials}")

if significant_trials > 0:
    print("\nSignificant trials details:")
    for idx in significant_indices:
        print(f"Trial {idx}:")
        print(f"  p-value = {p_values[idx]:.4f}")
        print(f"  True Covariance Matrix:\n{true_cov[idx]}")
        print(f"  Estimated Covariance Matrix:\n{estimated_cov[idx]}")
else:
    print("\nNo significant differences detected in covariance matrices.")
# Out:
# Number of significant trials: 16/100
# Mean p-value: 0.7679
# Skipped trials due to invalid determinants: 2
#
# Significant trials details:
# Trial 1:
#   p-value = 0.0000
#   True Covariance Matrix:
# [[0.35915464 0.62561476]
#  [0.62561476 1.26816154]]
#   Estimated Covariance Matrix:
# [[0.71736636 1.33318556]
#  [1.33318556 2.67393798]]
# Trial 2:
#   p-value = 0.0000
#   True Covariance Matrix:
# [[0.32822701 0.36852199]
#  [0.36852199 0.41472885]]
#   Estimated Covariance Matrix:
# [[0.82637463 0.92777158]
#  [0.92777158 1.04356988]]
# Trial 22:
#   p-value = 0.0000
#   True Covariance Matrix:
# [[0.99847698 0.64707917]
#  [0.64707917 0.52393013]]
#   Estimated Covariance Matrix:
# [[1.01993844 0.6603514 ]
#  [0.6603514  0.53446291]]
# Trial 34:
#   p-value = 0.0000
#   True Covariance Matrix:
# [[1.04576182 0.89872426]
#  [0.89872426 0.82705885]]
#   Estimated Covariance Matrix:
# [[1.071818   0.92186761]
#  [0.92186761 0.84891797]]
# Trial 46:
#   p-value = 0.0000
#   True Covariance Matrix:
# [[0.88395798 0.39642143]
#  [0.39642143 0.33551022]]
#   Estimated Covariance Matrix:
# [[0.88693462 0.39732295]
#  [0.39732295 0.33541355]]
# Trial 47:
#   p-value = 0.0029
#   True Covariance Matrix:
# [[0.53618133 0.6487602 ]
#  [0.6487602  0.87052155]]
#   Estimated Covariance Matrix:
# [[1.47094364 1.85626072]
#  [1.85626072 2.4333775 ]]
# Trial 50:
#   p-value = 0.0000
#   True Covariance Matrix:
# [[0.04460149 0.24786669]
#  [0.24786669 1.44449174]]
#   Estimated Covariance Matrix:
# [[0.04424436 0.24525659]
#  [0.24525659 1.42911126]]
# Trial 53:
#   p-value = 0.0196
#   True Covariance Matrix:
# [[0.2657406  0.51271451]
#  [0.51271451 1.03194678]]
#   Estimated Covariance Matrix:
# [[0.27378516 0.52677195]
#  [0.52677195 1.05894102]]
# Trial 57:
#   p-value = 0.0001
#   True Covariance Matrix:
# [[1.50283551 1.42108357]
#  [1.42108357 1.36545873]]
#   Estimated Covariance Matrix:
# [[1.90340232 1.8004762 ]
#  [1.8004762  1.7270149 ]]
# Trial 66:
#   p-value = 0.0001
#   True Covariance Matrix:
# [[0.11762147 0.16679642]
#  [0.16679642 0.77942055]]
#   Estimated Covariance Matrix:
# [[0.11814216 0.16907533]
#  [0.16907533 0.7826774 ]]
# Trial 74:
#   p-value = 0.0463
#   True Covariance Matrix:
# [[0.63572901 1.00487363]
#  [1.00487363 1.611166  ]]
#   Estimated Covariance Matrix:
# [[0.65056492 1.02782726]
#  [1.02782726 1.64810708]]
# Trial 78:
#   p-value = 0.0000
#   True Covariance Matrix:
# [[1.11411262 0.70505559]
#  [0.70505559 0.45957905]]
#   Estimated Covariance Matrix:
# [[1.46710746 0.92900498]
#  [0.92900498 0.60242767]]
# Trial 79:
#   p-value = 0.0045
#   True Covariance Matrix:
# [[1.59177995 1.40814996]
#  [1.40814996 1.25642252]]
#   Estimated Covariance Matrix:
# [[1.10077931 0.97014602]
#  [0.97014602 0.86778724]]
# Trial 84:
#   p-value = 0.0001
#   True Covariance Matrix:
# [[0.91732311 0.38253483]
#  [0.38253483 0.16614638]]
#   Estimated Covariance Matrix:
# [[0.88922685 0.36973246]
#  [0.36973246 0.16085664]]
# Trial 87:
#   p-value = 0.0000
#   True Covariance Matrix:
# [[0.44559541 0.35697904]
#  [0.35697904 0.37112308]]
#   Estimated Covariance Matrix:
# [[0.46084987 0.37004045]
#  [0.37004045 0.38272472]]
# Trial 92:
#   p-value = 0.0062
#   True Covariance Matrix:
# [[0.62694699 0.32227305]
#  [0.32227305 0.34214073]]
#   Estimated Covariance Matrix:
# [[0.62316365 0.31954437]
#  [0.31954437 0.33988587]]

# %%
# Plotting
plt.figure(figsize=(12, 6))

# Distribution of Test Statistics
plt.subplot(1, 2, 1)
plt.hist(test_statistics, alpha=0.7, edgecolor='k')
plt.axvline(np.mean(test_statistics), color='red', linestyle='--', label='Mean Test Statistic')
plt.title('Distribution of Test Statistics')
plt.xlabel('Test Statistic')
plt.ylabel('Frequency')
plt.legend()

# Distribution of p-values
plt.subplot(1, 2, 2)
plt.hist(p_values, alpha=0.7, edgecolor='k', color='orange')
plt.axvline(0.05, color='red', linestyle='--', label='Significance Threshold (p=0.05)')
plt.title('Distribution of p-values')
plt.xlabel('p-value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()
