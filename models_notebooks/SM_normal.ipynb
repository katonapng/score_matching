# %%
import json
import os
import sys
import time

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from scipy.stats import ttest_rel
from tqdm import tqdm

parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.insert(0, parent_dir)

from dataloader import FastTensorDataLoader

# %% [markdown]
# ## Data Generation

# %%
def generate_samples(mean, std, m, n):
    """
    Generate a list of samples drawn from a normal distribution.

    Args:
        mean (float): Mean of the normal distribution.
        std (float): Standard deviation of the normal distribution.
        m (int): Number of samples to generate.
        n (int): Number of elements in each sample.

    Returns:
        list[torch.Tensor]: A list of `m` tensors, each of shape (n, 1).
    """
    samples = []
    for _ in range(m):
        sample = torch.normal(mean=mean, std=std, size=(n,))
        sample = sample.unsqueeze(-1)  # Add the extra dimension
        samples.append(sample.clone())
    return samples

# %%
mean, std = 0, 1
m, n = 100, 1000
samples = generate_samples(mean, std, m, n)

# %%
train_size = int(0.8 * m)
test_size = m - train_size  # To ensure total matches `m`

X = torch.stack(samples, dim=0)

X_train = X[:train_size]
X_test = X[train_size:]

loader_train = FastTensorDataLoader(X_train, batch_size=32, shuffle=False)
loader_test = FastTensorDataLoader(X_test, batch_size=32, shuffle=False)

# %%
plt.figure(figsize=(5, 3))
plt.hist(X_train[0].numpy(), bins=50, color='blue', alpha=0.7, edgecolor='black')
plt.title('Histogram of Generated Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ## Model

# %%
class Gaussian_1d(nn.Module):
    def __init__(self):
        super(Gaussian_1d, self).__init__()
        self.mu = nn.Parameter(torch.randn(1, dtype=torch.float64))
        self.sigma = nn.Parameter(torch.abs(torch.randn(1, dtype=torch.float64)))

    def forward(self, x):
        diff = x - self.mu
        return -0.5 * (diff**2 / self.sigma**2)

    def compute_psi(self, x):
        x.requires_grad_()
        nn_output = self.forward(x).sum()
        psi = torch.autograd.grad(nn_output, x, create_graph=True)[0]
        return psi

    def loss(self, x_t):
        lengths = len(x_t)

        if not isinstance(x_t, torch.Tensor):
            x_t = torch.tensor(x_t, dtype=torch.float32)

        x_t = x_t.clone().detach().requires_grad_(True)
        psi_x = self.compute_psi(x_t)
        norm_squared = (psi_x ** 2).sum(dim=-1)

        divergence = 0
        for i in range(x_t.shape[-1]):
            gradient = torch.autograd.grad(psi_x[..., i].sum(), x_t, create_graph=True)[0]
            divergence += gradient[..., i]

        total_loss = 0.5 * norm_squared + divergence

        # Real value calculations
        psi_x_real = -(x_t - self.mu) / self.sigma**2
        norm_squared_real = (psi_x_real ** 2).sum(dim=-1)
        divergence_real = -1 / self.sigma**2

        real_loss = 0.5 * norm_squared_real + divergence_real

        # Average across batch
        total_loss = total_loss.sum() / lengths
        real_loss = real_loss.sum() / lengths

        return total_loss.mean(), real_loss.mean()

# %%
def optimize_theta_gaussian(
    loader_train, num_epochs=1000, learning_rate=1e-3,
):
    model = Gaussian_1d()
    optimizer = torch.optim.Rprop(model.parameters(), lr=learning_rate)

    losses, real_losses = [], []
    estimated_mus = []
    estimated_stds = []

    pbar = tqdm(range(num_epochs), desc="Training", unit="epoch")

    for _ in pbar:
        epoch_loss = 0.0
        epoch_real_loss = 0.0
        num_batches = 0

        start_time = time.time()
        for X_batch in loader_train:
            optimizer.zero_grad()

            loss, real_loss = model.loss(X_batch[0])
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            epoch_real_loss += real_loss.item()
            num_batches += 1

        epoch_loss /= num_batches
        epoch_real_loss /= num_batches

        losses.append(epoch_loss)
        real_losses.append(epoch_real_loss)
        estimated_mus.append(model.mu.detach().numpy().copy())
        estimated_stds.append(model.sigma.detach().numpy().copy())

        elapsed_time = time.time() - start_time
        pbar.set_postfix({
            "Train Loss": f"{epoch_loss:.4f}",
            "Real Loss": f"{epoch_real_loss:.4f}",
            "Time/Epoch": f"{elapsed_time:.2f}s"
        })

    return model, losses, real_losses, estimated_mus, estimated_stds

# %%
epochs = 100
model, losses, real_losses, estimated_mu, estimated_std = optimize_theta_gaussian(
    loader_train, num_epochs=epochs, learning_rate=1e-2)
# Out:
# Training: 100%|██████████| 100/100 [00:01<00:00, 52.22epoch/s, Train Loss=-497.5770, Real Loss=-497.5770, Time/Epoch=0.02s]

# %%
plt.plot(real_losses, linewidth=3, alpha=0.6, label="Analytical loss")
plt.plot(losses, label="Score Matching loss", linestyle='-')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Convergence for Score Matching 1d')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 3))
plt.plot(estimated_mu, label="Estimated μ")
plt.axhline(mean, color='orange', linestyle='--', label="True μ")
plt.xlabel('Epoch')
plt.ylabel('Value')
plt.grid(True)
plt.legend()
plt.title('Convergence of μ')
plt.show()

plt.figure(figsize=(6, 3))
plt.plot(estimated_std, label="Estimated σ")
plt.axhline(std, color='orange', linestyle='--', label="True σ")
plt.xlabel('Epoch')
plt.ylabel('Value')
plt.grid(True)
plt.legend()
plt.title('Convergence of σ')
plt.show()

# %%
print(f"Final estimated μ:, {estimated_mu[-1][0]:.4f}")
print("True μ:", mean)
print(f"\nFinal estimated σ: {estimated_std[-1][0]:.4f}")
print("True σ:\n", std)
# Out:
# Final estimated μ:, 0.0017
# True μ: 0
#
# Final estimated σ: 1.0010
# True σ:
#  1

# %% [markdown]
# ## Statistical Testing

# %%
num_trials = 100
epochs = 100
learning_rate = 1e-2
m, n = 100, 1000

true_mu = []
true_cov = []
estimated_mu = []
estimated_cov = []

# %%
json_file = 'data/trial_results.json'

# %%
if os.path.exists(json_file):
    with open(json_file, 'r') as f:
        trial_results = json.load(f)
else:
    trial_results = []

for trial in tqdm(range(num_trials), desc="Running trials"):
    mean = np.random.uniform(1, 5)
    std = np.random.uniform(1, 3)
    
    samples = generate_samples(mean, std, m, n)
    X = torch.stack(samples, dim=0)
    loader_train = FastTensorDataLoader(X, batch_size=32, shuffle=False)

    _, _, _, estimated_mu, estimated_std = optimize_theta_gaussian(
        loader_train, num_epochs=epochs, learning_rate=learning_rate)
    trial_result = {
        "trial": trial,
        "epochs": epochs,
        "lr": learning_rate,
        "true_mean": mean,
        "true_std": std,
        "estimated_mean": estimated_mu[-1][0].item(),
        "estimated_std": estimated_std[-1][0].item()
    }
    trial_results.append(trial_result)
    
    with open(json_file, mode='w') as f:
        json.dump(trial_results, f, indent=4)
# Out:
# Training: 100%|██████████| 100/100 [00:02<00:00, 36.23epoch/s, Train Loss=-60.8548, Real Loss=-60.8548, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 33.23epoch/s, Train Loss=-70.2396, Real Loss=-70.2396, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 32.33epoch/s, Train Loss=-59.6951, Real Loss=-59.6951, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:02<00:00, 38.15epoch/s, Train Loss=-249.3741, Real Loss=-249.3741, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:02<00:00, 40.98epoch/s, Train Loss=-382.0281, Real Loss=-382.0280, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:02<00:00, 33.37epoch/s, Train Loss=-57.9607, Real Loss=-57.9607, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 31.76epoch/s, Train Loss=-196.0528, Real Loss=-196.0528, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:02<00:00, 33.85epoch/s, Train Loss=-102.4871, Real Loss=-102.4871, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:02<00:00, 33.96epoch/s, Train Loss=-159.9866, Real Loss=-159.9866, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 23.84epoch/s, Train Loss=-400.4996, Real Loss=-400.4996, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 33.31epoch/s, Train Loss=-66.5768, Real Loss=-66.5768, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 23.65epoch/s, Train Loss=-97.4410, Real Loss=-97.4410, Time/Epoch=0.04s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.20epoch/s, Train Loss=-79.8547, Real Loss=-79.8547, Time/Epoch=0.04s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.20epoch/s, Train Loss=-69.3677, Real Loss=-69.3677, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 20.15epoch/s, Train Loss=-108.4029, Real Loss=-108.4029, Time/Epoch=0.04s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 22.43epoch/s, Train Loss=-123.6817, Real Loss=-123.6817, Time/Epoch=0.04s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 23.70epoch/s, Train Loss=-67.3191, Real Loss=-67.3191, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 27.53epoch/s, Train Loss=-66.6951, Real Loss=-66.6951, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 23.58epoch/s, Train Loss=-195.3124, Real Loss=-195.3124, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 23.73epoch/s, Train Loss=-233.3520, Real Loss=-233.3520, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 22.42epoch/s, Train Loss=-153.6967, Real Loss=-153.6967, Time/Epoch=0.05s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 22.98epoch/s, Train Loss=-92.5139, Real Loss=-92.5139, Time/Epoch=0.04s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 26.88epoch/s, Train Loss=-69.6921, Real Loss=-69.6921, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 26.51epoch/s, Train Loss=-65.2217, Real Loss=-65.2217, Time/Epoch=0.04s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 27.47epoch/s, Train Loss=-187.6582, Real Loss=-187.6582, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 27.75epoch/s, Train Loss=-309.6149, Real Loss=-309.6149, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 28.00epoch/s, Train Loss=-212.3303, Real Loss=-212.3303, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.96epoch/s, Train Loss=-176.2798, Real Loss=-176.2798, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.72epoch/s, Train Loss=-98.3281, Real Loss=-98.3281, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 23.54epoch/s, Train Loss=-75.2681, Real Loss=-75.2681, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.54epoch/s, Train Loss=-65.3285, Real Loss=-65.3285, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.33epoch/s, Train Loss=-78.9937, Real Loss=-78.9937, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 26.39epoch/s, Train Loss=-247.9852, Real Loss=-247.9852, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 27.78epoch/s, Train Loss=-112.6472, Real Loss=-112.6472, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.86epoch/s, Train Loss=-442.0376, Real Loss=-442.0376, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.18epoch/s, Train Loss=-79.1579, Real Loss=-79.1579, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.88epoch/s, Train Loss=-426.9494, Real Loss=-426.9494, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.42epoch/s, Train Loss=-218.1281, Real Loss=-218.1281, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 27.04epoch/s, Train Loss=-85.4551, Real Loss=-85.4551, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 27.16epoch/s, Train Loss=-209.6315, Real Loss=-209.6315, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.01epoch/s, Train Loss=-244.9081, Real Loss=-244.9081, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.14epoch/s, Train Loss=-478.7274, Real Loss=-478.7274, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 23.94epoch/s, Train Loss=-153.8210, Real Loss=-153.8210, Time/Epoch=0.04s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 23.50epoch/s, Train Loss=-70.9385, Real Loss=-70.9385, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.59epoch/s, Train Loss=-57.8569, Real Loss=-57.8569, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 27.04epoch/s, Train Loss=-67.0839, Real Loss=-67.0839, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.35epoch/s, Train Loss=-75.3726, Real Loss=-75.3726, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.23epoch/s, Train Loss=-126.7766, Real Loss=-126.7766, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.37epoch/s, Train Loss=-279.1940, Real Loss=-279.1940, Time/Epoch=0.04s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.20epoch/s, Train Loss=-120.5360, Real Loss=-120.5360, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.43epoch/s, Train Loss=-148.7586, Real Loss=-148.7586, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.08epoch/s, Train Loss=-149.0853, Real Loss=-149.0853, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 26.72epoch/s, Train Loss=-178.4750, Real Loss=-178.4750, Time/Epoch=0.04s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.25epoch/s, Train Loss=-467.6263, Real Loss=-467.6263, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.80epoch/s, Train Loss=-84.7172, Real Loss=-84.7172, Time/Epoch=0.04s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 26.68epoch/s, Train Loss=-293.1911, Real Loss=-293.1911, Time/Epoch=0.06s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.60epoch/s, Train Loss=-162.4324, Real Loss=-162.4324, Time/Epoch=0.05s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.22epoch/s, Train Loss=-151.4670, Real Loss=-151.4670, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.37epoch/s, Train Loss=-182.5943, Real Loss=-182.5943, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.98epoch/s, Train Loss=-340.8138, Real Loss=-340.8138, Time/Epoch=0.04s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.18epoch/s, Train Loss=-68.6339, Real Loss=-68.6339, Time/Epoch=0.04s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.62epoch/s, Train Loss=-79.4026, Real Loss=-79.4026, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 26.38epoch/s, Train Loss=-111.9985, Real Loss=-111.9985, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.85epoch/s, Train Loss=-139.5214, Real Loss=-139.5214, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.47epoch/s, Train Loss=-72.0814, Real Loss=-72.0814, Time/Epoch=0.04s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.70epoch/s, Train Loss=-59.9361, Real Loss=-59.9361, Time/Epoch=0.04s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 23.82epoch/s, Train Loss=-248.7901, Real Loss=-248.7901, Time/Epoch=0.04s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.94epoch/s, Train Loss=-71.7985, Real Loss=-71.7985, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.41epoch/s, Train Loss=-405.3264, Real Loss=-405.3264, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.48epoch/s, Train Loss=-58.7373, Real Loss=-58.7373, Time/Epoch=0.07s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.87epoch/s, Train Loss=-116.3201, Real Loss=-116.3201, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.93epoch/s, Train Loss=-237.5437, Real Loss=-237.5437, Time/Epoch=0.07s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.48epoch/s, Train Loss=-311.5886, Real Loss=-311.5886, Time/Epoch=0.04s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.56epoch/s, Train Loss=-59.7785, Real Loss=-59.7785, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.20epoch/s, Train Loss=-96.5774, Real Loss=-96.5774, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.05epoch/s, Train Loss=-163.2213, Real Loss=-163.2213, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.51epoch/s, Train Loss=-78.5634, Real Loss=-78.5634, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.49epoch/s, Train Loss=-339.5572, Real Loss=-339.5572, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.08epoch/s, Train Loss=-251.0965, Real Loss=-251.0965, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.64epoch/s, Train Loss=-80.1600, Real Loss=-80.1600, Time/Epoch=0.06s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 26.53epoch/s, Train Loss=-113.4957, Real Loss=-113.4957, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.87epoch/s, Train Loss=-164.2537, Real Loss=-164.2537, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.86epoch/s, Train Loss=-333.4298, Real Loss=-333.4298, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.38epoch/s, Train Loss=-134.0606, Real Loss=-134.0606, Time/Epoch=0.04s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 23.75epoch/s, Train Loss=-104.1900, Real Loss=-104.1900, Time/Epoch=0.05s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.29epoch/s, Train Loss=-72.1286, Real Loss=-72.1286, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 23.95epoch/s, Train Loss=-139.3077, Real Loss=-139.3077, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.10epoch/s, Train Loss=-211.6883, Real Loss=-211.6883, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.74epoch/s, Train Loss=-85.6341, Real Loss=-85.6340, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.47epoch/s, Train Loss=-85.3240, Real Loss=-85.3240, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.57epoch/s, Train Loss=-55.1911, Real Loss=-55.1911, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.33epoch/s, Train Loss=-90.8425, Real Loss=-90.8425, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 23.41epoch/s, Train Loss=-109.7330, Real Loss=-109.7330, Time/Epoch=0.04s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.86epoch/s, Train Loss=-71.1009, Real Loss=-71.1009, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.57epoch/s, Train Loss=-156.6168, Real Loss=-156.6168, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.76epoch/s, Train Loss=-251.5176, Real Loss=-251.5176, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.79epoch/s, Train Loss=-165.7409, Real Loss=-165.7409, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 23.66epoch/s, Train Loss=-288.1717, Real Loss=-288.1717, Time/Epoch=0.02s]
# Training: 100%|██████████| 100/100 [00:04<00:00, 24.13epoch/s, Train Loss=-151.7057, Real Loss=-151.7057, Time/Epoch=0.03s]
# Training: 100%|██████████| 100/100 [00:03<00:00, 25.73epoch/s, Train Loss=-74.8601, Real Loss=-74.8601, Time/Epoch=0.04s]
# Running trials: 100%|██████████| 100/100 [06:31<00:00,  3.91s/it]

# %%
with open(json_file, mode='r') as f:
    trial_results = json.load(f)

true_mu = np.array([trial['true_mean'] for trial in trial_results])
true_cov = np.array([trial['true_std'] for trial in trial_results])
estimated_mu = np.array([trial['estimated_mean'] for trial in trial_results])
estimated_cov = np.array([trial['estimated_std'] for trial in trial_results])

# %%
mean_ttest = ttest_rel(true_mu, estimated_mu)
std_ttest = ttest_rel(true_cov, estimated_cov)

print(f"Mean difference (paired t-test): p-value = {mean_ttest.pvalue}")
print(f"Variance difference (paired t-test): p-value = {std_ttest.pvalue}")

alpha = 0.05
if mean_ttest.pvalue < alpha:
    print("The model produces statistically significant differences in estimated means.")
else:
    print("No statistically significant difference in estimated means.")

if std_ttest.pvalue < alpha:
    print("The model produces statistically significant differences in estimated variances.")
else:
    print("No statistically significant difference in estimated variances.")
# Out:
# Mean difference (paired t-test): p-value = 0.7409132520923929
# Variance difference (paired t-test): p-value = 0.8751214788594812
# No statistically significant difference in estimated means.
# No statistically significant difference in estimated variances.
